# %%
import pandas as pd
import numpy as np
import requests
from time import sleep

# %%
headers = {'Cookie': '_gcl_au=1.1.1018492616.1654861675; tk_or=%22https%3A%2F%2Fwww.google.com%2F%22; _fbp=fb.1.1654861680272.1737963368; _hjSessionUser_2739501=eyJpZCI6IjYyY2QzNDU0LTk4ZWMtNTBiYi1iMWJjLWQwMjNkYTM0ZTRlZiIsImNyZWF0ZWQiOjE2NTQ4NjE2ODA1NDQsImV4aXN0aW5nIjp0cnVlfQ==; usetiful-visitor-ident=a8f91f19-1fa3-4ac8-31aa-1708dae1bb09; crisp-client%2Fsession%2F2dc87a17-fcbe-4c6b-ac38-cbd56e9e2376=session_b17d699e-12b9-4efa-8bc5-d18afb10ef1f; crisp-client%2Fsocket%2F2dc87a17-fcbe-4c6b-ac38-cbd56e9e2376=1; _tcfpup=1657190242155; ti_ukp=88464a3d.db6d.32db.0076.2f019bfe974e; _oauth_id_token_cookie_sub=628a43323f3cf5bd228b7d2d; _gid=GA1.2.244785558.1657454838; tk_r3d=%22https%3A%2F%2Fwww.google.com%2F%22; _oauth_id_token_cookie=6d4ab3444a4ceedc08593e7827f62d63-4e3b440afed7182eebd965d6404a2df7-c208fcf8fcb045cc838398bb6eaa4c8b-fa929a210d3c145de9844fffa159a221; tk_lr=%22%22; _hjSession_2739501=eyJpZCI6IjE0YzkzZDE5LTgxODAtNDIzNy1iYTA4LTM0NWM0OWJlNzViMiIsImNyZWF0ZWQiOjE2NTc3MTU3OTIzMTIsImluU2FtcGxlIjpmYWxzZX0=; _hjAbsoluteSessionInProgress=0; _ga=GA1.2.2136330129.1654861678; _tcSessInfo={"timestamp":1657718049930,"pageView":0}; _tcSecSess={"sess":"d48167b99e82f5ee8b0fa473136","device_type":"desktop","ip":"45.14.71.x","tcvfp":"baad5b2b-e6de-adf2-3460-9da708465157","locale":"ru_RU","country":"NL","city":"","region":"","timestamp":1657718053032}; _tcafterScoket=1; PHPSESSID=at7326eq3arro2n96deqm84et4; _oauth_id_token=KVS_SUB628a43323f3cf5bd228b7d2d; _ga_E61RPSQPM7=GS1.1.1657718048.18.1.1657718069.0'}

# %%
# Получим список стран, отраслей и размеров компаний с сайта 
enum = requests.get(
    "https://apps.growmeorganic.com/api-product/load-filters-companies",
    headers=headers
).json()

# %%
# enum

# %%
# Создадим отдельные списки для каждого критерия отбора
countries = list(map(lambda x: x['query'], enum['countries']))
industries = list(map(lambda x: x['query'], enum['industries']))
sizes = list(map(lambda x: x['query'], enum['sizes']))

# %%
# industries

# %%
SIZES = sizes

# %%
SIZES
# Out:
# ['1-10',
#  '10001+',
#  '1001-5000',
#  '11-50',
#  '201-500',
#  '5001-10000',
#  '501-1000',
#  '51-200',
#  'Myself only']

# %%
def url_parser(country, industry, sizes=SIZES) -> dict:
     
    # Создадим пустой список ссылок с ключом 'industry'
    country_companies[country][industry] = []
    
    count = 0
    for size in sizes:

        count = count + 1

        # Отправим post запрос с требуемыми критериями
        requests.post('https://apps.growmeorganic.com/api-product/trigger-company-explorer-task', 
                       headers=headers,
                       data = {"country"  : country,
                               "industry" : industry,
                               "size"     : size}) 

        # Пока ссылка не появится в списке, дальше не пойдем 
        while len(country_companies[country][industry]) < count:

            #Имитируем ожидание
            sleep(6*float(np.random.rand(1)))

            # Отправим get запрос, чтобы получить ссылку на нужные данные
            try:
                    file_url = requests.get('https://apps.growmeorganic.com/api-product/load-companies-tasks-exported', 
                                                                             headers=headers).json()['data'][0]['file_url']
                    if file_url != None:
                        country_companies[country][industry].append(file_url)
            except:
                    pass

    return country_companies

# %%
country = "Moldova"
industry = "Utilities"
size = "1-10"

response = requests.post('https://apps.growmeorganic.com/api-product/trigger-company-explorer-task', 
                       headers=headers,
                       data = {"country": country,
                               "industry" : industry,
                               "size"     : size})

# %%
response.json()
# Out:
# {'state': True}

# %%
list(filter(lambda x: x["country"]=='France', requests.get('https://apps.growmeorganic.com/api-product/load-companies-tasks-exported', 
             headers=headers).json()["data"]))
# Out:
# [{'_id': '62ca8b3b3f3cf5e5318b63ae',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-1350-628a43323f3cf5bd228b7d2d-france-writing-and-editing-myself-only.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': 'Myself Only',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657441083,
#   'in_process': True,
#   'total_do_do': 147,
#   'total_done': 101,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-7561-628a43323f3cf5bd228b7d2d-france-writing-and-editing-myself-only.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca8b093f3cf5ae298b6b40',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-2541-628a43323f3cf5bd228b7d2d-france-writing-and-editing-51-200.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': '51-200',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657441033,
#   'in_process': True,
#   'total_do_do': 14,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-9254-628a43323f3cf5bd228b7d2d-france-writing-and-editing-51-200.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca8af83f3cf5c5318b61d0',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-1546-628a43323f3cf5bd228b7d2d-france-writing-and-editing-501-1000.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': '501-1000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657441016,
#   'in_process': True,
#   'total_do_do': 1,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3349-628a43323f3cf5bd228b7d2d-france-writing-and-editing-501-1000.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca8ac23f3cf5a8298b696b',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-6806-628a43323f3cf5bd228b7d2d-france-writing-and-editing-5001-10000.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': '5001-10000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657440962,
#   'in_process': True,
#   'total_do_do': 0,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-8564-628a43323f3cf5bd228b7d2d-france-writing-and-editing-5001-10000.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca8a853f3cf5a1298b62f8',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-2398-628a43323f3cf5bd228b7d2d-france-writing-and-editing-201-500.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': '201-500',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657440901,
#   'in_process': True,
#   'total_do_do': 2,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-4235-628a43323f3cf5bd228b7d2d-france-writing-and-editing-201-500.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca8a473f3cf5b5298b66df',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-4964-628a43323f3cf5bd228b7d2d-france-writing-and-editing-11-50.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': '11-50',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657440839,
#   'in_process': True,
#   'total_do_do': 43,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-400-628a43323f3cf5bd228b7d2d-france-writing-and-editing-11-50.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca8a153f3cf5b1298b6314',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3070-628a43323f3cf5bd228b7d2d-france-writing-and-editing-1001-5000.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': '1001-5000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657440789,
#   'in_process': True,
#   'total_do_do': 1,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-4159-628a43323f3cf5bd228b7d2d-france-writing-and-editing-1001-5000.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca8a0c3f3cf5ae298b6a9e',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3998-628a43323f3cf5bd228b7d2d-france-writing-and-editing-10001.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': '10001+',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657440780,
#   'in_process': True,
#   'total_do_do': 0,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-6771-628a43323f3cf5bd228b7d2d-france-writing-and-editing-10001.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca89da3f3cf5a6298b6356',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-7235-628a43323f3cf5bd228b7d2d-france-writing-and-editing-1-10.xlsx',
#   'country': 'France',
#   'industry': 'Writing And Editing',
#   'size': '1-10',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657440730,
#   'in_process': True,
#   'total_do_do': 117,
#   'total_done': 101,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-4441-628a43323f3cf5bd228b7d2d-france-writing-and-editing-1-10.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca89d03f3cf5c7318b62aa',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3347-628a43323f3cf5bd228b7d2d-france-wireless-myself-only.xlsx',
#   'country': 'France',
#   'industry': 'Wireless',
#   'size': 'Myself Only',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657440720,
#   'in_process': True,
#   'total_do_do': 44,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-5807-628a43323f3cf5bd228b7d2d-france-wireless-myself-only.csv',
#   'isFinished': 'true'},
#  {'_id': '62

#   'in_process': True,
#   'total_do_do': 0,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-2277-628a43323f3cf5bd228b7d2d-france-utilities-5001-10000.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7ff83f3cf5e9318b5a8d',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3593-628a43323f3cf5bd228b7d2d-france-utilities-201-500.xlsx',
#   'country': 'France',
#   'industry': 'Utilities',
#   'size': '201-500',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657438200,
#   'in_process': True,
#   'total_do_do': 1,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-2175-628a43323f3cf5bd228b7d2d-france-utilities-201-500.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7fc63f3cf5a9298b5e08',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-2673-628a43323f3cf5bd228b7d2d-france-utilities-11-50.xlsx',
#   'country': 'France',
#   'industry': 'Utilities',
#   'size': '11-50',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657438150,
#   'in_process': True,
#   'total_do_do': 21,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-7538-628a43323f3cf5bd228b7d2d-france-utilities-11-50.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7fba3f3cf5ac298b5bda',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-1441-628a43323f3cf5bd228b7d2d-france-utilities-1001-5000.xlsx',
#   'country': 'France',
#   'industry': 'Utilities',
#   'size': '1001-5000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657438138,
#   'in_process': True,
#   'total_do_do': 0,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-4954-628a43323f3cf5bd228b7d2d-france-utilities-1001-5000.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7f893f3cf5ae298b62e6',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-2055-628a43323f3cf5bd228b7d2d-france-utilities-10001.xlsx',
#   'country': 'France',
#   'industry': 'Utilities',
#   'size': '10001+',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657438089,
#   'in_process': True,
#   'total_do_do': 2,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-9728-628a43323f3cf5bd228b7d2d-france-utilities-10001.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7f7f3f3cf5ca318b5ae4',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-2188-628a43323f3cf5bd228b7d2d-france-utilities-1-10.xlsx',
#   'country': 'France',
#   'industry': 'Utilities',
#   'size': '1-10',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657438079,
#   'in_process': True,
#   'total_do_do': 44,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-9673-628a43323f3cf5bd228b7d2d-france-utilities-1-10.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7f433f3cf5c4318b578e',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3657-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-myself-only.xlsx',
#   'country': 'France',
#   'industry': 'Transportation/trucking/railroad',
#   'size': 'Myself Only',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657438019,
#   'in_process': True,
#   'total_do_do': 282,
#   'total_done': 201,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-530-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-myself-only.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7f0f3f3cf5ea318b59de',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-8133-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-51-200.xlsx',
#   'country': 'France',
#   'industry': 'Transportation/trucking/railroad',
#   'size': '51-200',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657437967,
#   'in_process': True,
#   'total_do_do': 78,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3691-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-51-200.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7f053f3cf5106b8b5436',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3764-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-501-1000.xlsx',
#   'country': 'France',
#   'industry': 'Transportation/trucking/railroad',
#   'size': '501-1000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657437957,
#   'in_process': True,
#   'total_do_do': 7,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-1985-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-501-1000.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7ed53f3cf5a2298b6903',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-1925-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-5001-10000.xlsx',
#   'country': 'France',
#   'industry': 'Transportation/trucking/railroad',
#   'size': '5001-10000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657437909,
#   'in_process': True,
#   'total_do_do': 1,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-6009-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-5001-10000.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7ecb3f3cf5c3318b5b29',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-6250-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-201-500.xlsx',
#   'country': 'France',
#   'industry': 'Transportation/trucking/railroad',
#   'size': '201-500',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657437899,
#   'in_process': True,
#   'total_do_do': 25,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-3157-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-201-500.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7e943f3cf5c6318b5b77',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-2122-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-11-50.xlsx',
#   'country': 'France',
#   'industry': 'Transportation/trucking/railroad',
#   'size': '11-50',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657437844,
#   'in_process': True,
#   'total_do_do': 237,
#   'total_done': 201,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-10-9814-628a43323f3cf5bd228b7d2d-france-transportation-trucking-railroad-11-50.csv',
#   'isFinished': 'true'},
#  {'_id': '62ca7e563f3cf5a2298b68bc',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
# ...
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-8533-628a43323f3cf5bd228b7d2d-france-facilities-services-501-1000.xlsx',
#   'country': 'France',
#   'industry': 'Facilities Services',
#   'size': '501-1000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657400942,
#   'in_process': True,
#   'total_do_do': 3,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-7259-628a43323f3cf5bd228b7d2d-france-facilities-services-501-1000.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9ee333f3cf59c718b69d4',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-8333-628a43323f3cf5bd228b7d2d-france-facilities-services-5001-10000.xlsx',
#   'country': 'France',
#   'industry': 'Facilities Services',
#   'size': '5001-10000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657400883,
#   'in_process': True,
#   'total_do_do': 1,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-3153-628a43323f3cf5bd228b7d2d-france-facilities-services-5001-10000.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9ee003f3cf5b5718b57de',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-8644-628a43323f3cf5bd228b7d2d-france-facilities-services-201-500.xlsx',
#   'country': 'France',
#   'industry': 'Facilities Services',
#   'size': '201-500',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657400832,
#   'in_process': True,
#   'total_do_do': 4,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-8757-628a43323f3cf5bd228b7d2d-france-facilities-services-201-500.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9edf33f3cf52f408b50ff',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-9320-628a43323f3cf5bd228b7d2d-france-facilities-services-11-50.xlsx',
#   'country': 'France',
#   'industry': 'Facilities Services',
#   'size': '11-50',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657400819,
#   'in_process': True,
#   'total_do_do': 63,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-8769-628a43323f3cf5bd228b7d2d-france-facilities-services-11-50.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9edbb3f3cf5bc718b54be',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-621-628a43323f3cf5bd228b7d2d-france-facilities-services-1001-5000.xlsx',
#   'country': 'France',
#   'industry': 'Facilities Services',
#   'size': '1001-5000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657400763,
#   'in_process': True,
#   'total_do_do': 2,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-2775-628a43323f3cf5bd228b7d2d-france-facilities-services-1001-5000.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9ed7d3f3cf52a408b503a',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09

#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657399922,
#   'in_process': True,
#   'total_do_do': 7,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-5700-628a43323f3cf5bd228b7d2d-france-events-services-201-500.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9ea383f3cf5ab718b55f0',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-9755-628a43323f3cf5bd228b7d2d-france-events-services-11-50.xlsx',
#   'country': 'France',
#   'industry': 'Events Services',
#   'size': '11-50',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657399864,
#   'in_process': True,
#   'total_do_do': 424,
#   'total_done': 401,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-368-628a43323f3cf5bd228b7d2d-france-events-services-11-50.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9ea043f3cf588718b55b6',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-8353-628a43323f3cf5bd228b7d2d-france-events-services-1001-5000.xlsx',
#   'country': 'France',
#   'industry': 'Events Services',
#   'size': '1001-5000',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657399812,
#   'in_process': True,
#   'total_do_do': 4,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-5797-628a43323f3cf5bd228b7d2d-france-events-services-1001-5000.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9e9f93f3cf5ba718b53b0',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-2936-628a43323f3cf5bd228b7d2d-france-events-services-10001.xlsx',
#   'country': 'France',
#   'industry': 'Events Services',
#   'size': '10001+',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657399801,
#   'in_process': True,
#   'total_do_do': 1,
#   'total_done': 0,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-9145-628a43323f3cf5bd228b7d2d-france-events-services-10001.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9e9c63f3cf59f718b5385',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-8444-628a43323f3cf5bd228b7d2d-france-events-services-1-10.xlsx',
#   'country': 'France',
#   'industry': 'Events Services',
#   'size': '1-10',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657399750,
#   'in_process': True,
#   'total_do_do': 975,
#   'total_done': 901,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-2529-628a43323f3cf5bd228b7d2d-france-events-services-1-10.csv',
#   'isFinished': 'true'},
#  {'_id': '62c9e9bc3f3cf52e408b4fc9',
#   'owner': {'$id': '628a43323f3cf5bd228b7d2d'},
#   'finished': True,
#   'file_url': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-6159-628a43323f3cf5bd228b7d2d-france-environmental-services-myself-only.xlsx',
#   'country': 'France',
#   'industry': 'Environmental Services',
#   'size': 'Myself Only',
#   'is_paying': True,
#   'usage': 0,
#   'last_query': 1657399740,
#   'in_process': True,
#   'total_do_do': 187,
#   'total_done': 101,
#   'file_csv': 'https://images987.s3-us-west-1.amazonaws.com/2022-Jul-09-7896-628a43323f3cf5bd228b7d2d-france-environmental-services-myself-only.csv',
#   'isFinished': 'true'},
#  ...]

# %%
def urls_to_excel():
    # Выгрузим получившиеся ссылки
    file_url = requests.get('https://apps.growmeorganic.com/api-product/load-companies-tasks-exported', 
                                                                             headers=headers).json()
    u = [url['file_url'] for url in file_url['data']]
    
    data = pd.DataFrame()

    for url in u:
    
        excel = pd.read_excel(url)
        data = data.concat([aust,excel])
    
    data.drop_duplicates(keep='last').to_excel('Downloads/data.xlsx')

# %%
file_url = requests.get('https://apps.growmeorganic.com/api-product/load-companies-tasks-exported', 
                                                                             headers=headers).json()
u = [url['file_url'] for url in file_url['data']]#

# %%
country = 'Belgium'
country_companies = {country:{}}

for industry in industries:
    country_companies = url_parser(country, industry)

# %%
data = pd.read_excel('Downloads/data/data.xlsx')

# %%
data.groupby('country').count()['name']

# %%
import datetime
import calendar

# %%
current_timestamp = calendar.timegm(datetime.datetime.utcnow().utctimetuple())

# %%
current_timestamp
# Out:
# 1657466848

# %%
country = 'United States'
industry = 'Accounting'
size = '1-10'

# %%
f"""insert into tasks (country, industry, size, timestamp)
            values ({country}, {industry}, {size})
                """
# Out:
# 'insert into tasks (country, industry, size, timestamp)\n            values (United States, Accounting, 1-10)\n                '
